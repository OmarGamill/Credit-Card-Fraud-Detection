# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df.head(10)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  119191.0  2.052427 -0.133236 -1.740621  0.277935  0.337999 -0.826933
# 1   71750.0  1.220356 -0.159191 -0.444349 -0.094437  0.104457 -0.345790
# 2  151977.0  0.892824 -1.440698 -0.637940  3.912871  0.099291  2.433288
# 3   55709.0 -3.146021  2.247634  0.901397  0.146162 -2.109360 -0.148312
# 4   66654.0  1.194996 -0.007495  0.301285  0.750199 -0.297494 -0.405836
# 5  138816.0  2.288281 -0.575108 -2.600038 -1.321918  0.676592 -0.634091
# 6     862.0  1.174297  0.180652  0.513432  0.450884 -0.197997 -0.186938
# 7   52532.0  0.797464 -0.947293  1.045822  0.263474 -1.194980  0.348919
# 8  140993.0  0.173434  0.537613 -1.402600 -1.207961  1.372947 -0.853390
# 9  120210.0 -1.111080  0.298477  0.611207 -2.660377  0.214494  0.072039
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.334629 -0.227039  0.267655  ... -0.006518  0.121300  0.037733 -0.356498
# ...

# %%
df.shape
# Out:
# (170884, 31)

# %%
y_train=df['Class'].to_numpy().reshape(-1,1)
x_train=df.drop('Class',axis=1).to_numpy()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score,accuracy_score,classification_report

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\omar gamel\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\omar gamel\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_perdic=model.predict(x_train)
accuracy=accuracy_score(y_train,y_perdic)
f1Score=f1_score(y_train, y_perdic)
print(f'accuracy: {accuracy} and f1_score: {f1Score}')
# Out:
# accuracy: 0.9990227288687062 and f1_score: 0.7202680067001674

# %%
report=classification_report(y_train, y_perdic)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    170579
#            1       0.74      0.70      0.72       305
#
#     accuracy                           1.00    170884
#    macro avg       0.87      0.85      0.86    170884
# weighted avg       1.00      1.00      1.00    170884

# %%
val_data=pd.read_csv('val.csv')
y_val=val_data['Class'].to_numpy().reshape(-1,1)
x_val=val_data.drop('Class', axis=1).to_numpy()

# %%
y_perdic_val=model.predict(x_val)
report2=classification_report(y_val,y_perdic_val)
print(report2)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56870
#            1       0.71      0.69      0.70        90
#
#     accuracy                           1.00     56960
#    macro avg       0.86      0.84      0.85     56960
# weighted avg       1.00      1.00      1.00     56960
